# %%
from data_loading_utils import load_final_data

# %%
final_data, y = load_final_data()
final_data
# Out:
# Applying feature engineering...
# c:\Users\midon\Documents\anomaly-detection-autoencoder-based-basic\.venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Applying Yeo-Johnson transformations...
# Adding boolean features and non_log features...
#         DISBURSED_AMOUNT  ASSET_COST  PRI_NO_OF_ACCTS  PRI_ACTIVE_ACCTS  \
# 0              10.831294   10.975090         0.095310          0.095310
# 1              10.761007   11.090585         0.741937          0.741937
# 2              10.883299   11.024531         0.095310          0.095310
# 3              10.959785   11.099137         1.410987          0.095310
# 4              10.866263   11.007106         0.095310          0.095310
# ...                  ...         ...              ...               ...
# 233149         11.054283   11.565576         1.629241          1.410987
# ...
